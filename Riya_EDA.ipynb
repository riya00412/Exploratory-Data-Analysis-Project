# %% [markdown]
# <a href="https://colab.research.google.com/github/riya00412/Exploratory-Data-Analysis-Project/blob/main/Riya_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1: Exploratory Data Analysis (EDA) and Business Insights

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
data1=pd.read_csv("/content/Customers.csv")
display(data1)
data2=pd.read_csv("/content/Products.csv")
display(data2)
data3=pd.read_csv("/content/Transactions.csv")
display(data3)
# Out:
#     CustomerID        CustomerName         Region  SignupDate
# 0        C0001    Lawrence Carroll  South America  2022-07-10
# 1        C0002      Elizabeth Lutz           Asia  2022-02-13
# 2        C0003      Michael Rivera  South America  2024-03-07
# 3        C0004  Kathleen Rodriguez  South America  2022-10-09
# 4        C0005         Laura Weber           Asia  2022-08-15
# ..         ...                 ...            ...         ...
# 195      C0196         Laura Watts         Europe  2022-06-07
# 196      C0197    Christina Harvey         Europe  2023-03-21
# 197      C0198         Rebecca Ray         Europe  2022-02-27
# 198      C0199      Andrea Jenkins         Europe  2022-12-03
# 199      C0200         Kelly Cross           Asia  2023-06-11
#
# [200 rows x 4 columns]
#    ProductID              ProductName     Category   Price
# 0       P001     ActiveWear Biography        Books  169.30
# 1       P002    ActiveWear Smartwatch  Electronics  346.30
# ...

# %%
data1.isnull().sum()
data1.dropna()
# Out:
#     CustomerID        CustomerName         Region  SignupDate
# 0        C0001    Lawrence Carroll  South America  2022-07-10
# 1        C0002      Elizabeth Lutz           Asia  2022-02-13
# 2        C0003      Michael Rivera  South America  2024-03-07
# 3        C0004  Kathleen Rodriguez  South America  2022-10-09
# 4        C0005         Laura Weber           Asia  2022-08-15
# ..         ...                 ...            ...         ...
# 195      C0196         Laura Watts         Europe  2022-06-07
# 196      C0197    Christina Harvey         Europe  2023-03-21
# 197      C0198         Rebecca Ray         Europe  2022-02-27
# 198      C0199      Andrea Jenkins         Europe  2022-12-03
# 199      C0200         Kelly Cross           Asia  2023-06-11
#
# [200 rows x 4 columns]

# %%
data2.isnull().sum()
data2.dropna()
# Out:
#    ProductID              ProductName     Category   Price
# 0       P001     ActiveWear Biography        Books  169.30
# 1       P002    ActiveWear Smartwatch  Electronics  346.30
# 2       P003  ComfortLiving Biography        Books   44.12
# 3       P004            BookWorld Rug   Home Decor   95.69
# 4       P005          TechPro T-Shirt     Clothing  429.31
# ..       ...                      ...          ...     ...
# 95      P096     SoundWave Headphones  Electronics  307.47
# 96      P097       BookWorld Cookbook        Books  319.34
# 97      P098         SoundWave Laptop  Electronics  299.93
# 98      P099   SoundWave Mystery Book        Books  354.29
# 99      P100        HomeSense Sweater     Clothing  126.34
#
# [100 rows x 4 columns]

# %%
data3.isnull().sum()
data3.dropna()
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0          T00001      C0199      P067  2024-08-25 12:38:23         1
# 1          T00112      C0146      P067  2024-05-27 22:23:54         1
# 2          T00166      C0127      P067  2024-04-25 07:38:55         1
# 3          T00272      C0087      P067  2024-03-26 22:55:37         2
# 4          T00363      C0070      P067  2024-03-21 15:10:10         3
# ..            ...        ...       ...                  ...       ...
# 995        T00496      C0118      P037  2024-10-24 08:30:27         1
# 996        T00759      C0059      P037  2024-06-04 02:15:24         3
# 997        T00922      C0018      P037  2024-04-05 13:05:32         4
# 998        T00959      C0115      P037  2024-09-29 10:16:02         2
# 999        T00992      C0024      P037  2024-04-21 10:52:24         1
#
#      TotalValue   Price
# 0        300.68  300.68
# 1        300.68  300.68
# 2        300.68  300.68
# 3        601.36  300.68
# ...

# %%
# data1.dtypes
data1.count()
# Out:
# CustomerID      200
# CustomerName    200
# Region          200
# SignupDate      200
# dtype: int64

# %%
duplicate_rows_df = data1[data1.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 4)

# %%
duplicate_rows_df = data2[data2.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 4)

# %%
duplicate_rows_df = data3[data3.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 7)

# %%
data1.drop_duplicates(inplace=True)
print(data1.count)
# Out:
# <bound method DataFrame.count of     CustomerID        CustomerName         Region  SignupDate
# 0        C0001    Lawrence Carroll  South America  2022-07-10
# 1        C0002      Elizabeth Lutz           Asia  2022-02-13
# 2        C0003      Michael Rivera  South America  2024-03-07
# 3        C0004  Kathleen Rodriguez  South America  2022-10-09
# 4        C0005         Laura Weber           Asia  2022-08-15
# ..         ...                 ...            ...         ...
# 195      C0196         Laura Watts         Europe  2022-06-07
# 196      C0197    Christina Harvey         Europe  2023-03-21
# 197      C0198         Rebecca Ray         Europe  2022-02-27
# 198      C0199      Andrea Jenkins         Europe  2022-12-03
# 199      C0200         Kelly Cross           Asia  2023-06-11
#
# [200 rows x 4 columns]>

# %%
data2.drop_duplicates(inplace=True)
print(data2.count)
# Out:
# <bound method DataFrame.count of    ProductID              ProductName     Category   Price
# 0       P001     ActiveWear Biography        Books  169.30
# 1       P002    ActiveWear Smartwatch  Electronics  346.30
# 2       P003  ComfortLiving Biography        Books   44.12
# 3       P004            BookWorld Rug   Home Decor   95.69
# 4       P005          TechPro T-Shirt     Clothing  429.31
# ..       ...                      ...          ...     ...
# 95      P096     SoundWave Headphones  Electronics  307.47
# 96      P097       BookWorld Cookbook        Books  319.34
# 97      P098         SoundWave Laptop  Electronics  299.93
# 98      P099   SoundWave Mystery Book        Books  354.29
# 99      P100        HomeSense Sweater     Clothing  126.34
#
# [100 rows x 4 columns]>

# %%
data3.drop_duplicates(inplace=True)
print(data3.count)
# Out:
# <bound method DataFrame.count of     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 0          T00001      C0199      P067  2024-08-25 12:38:23         1
# 1          T00112      C0146      P067  2024-05-27 22:23:54         1
# 2          T00166      C0127      P067  2024-04-25 07:38:55         1
# 3          T00272      C0087      P067  2024-03-26 22:55:37         2
# 4          T00363      C0070      P067  2024-03-21 15:10:10         3
# ..            ...        ...       ...                  ...       ...
# 995        T00496      C0118      P037  2024-10-24 08:30:27         1
# 996        T00759      C0059      P037  2024-06-04 02:15:24         3
# 997        T00922      C0018      P037  2024-04-05 13:05:32         4
# 998        T00959      C0115      P037  2024-09-29 10:16:02         2
# 999        T00992      C0024      P037  2024-04-21 10:52:24         1
#
#      TotalValue   Price
# 0        300.68  300.68
# 1        300.68  300.68
# ...

# %%
data1["SignupDate"]=pd.to_datetime(data1["SignupDate"])
print(data1.dtypes)
data3["TransactionDate"]=pd.to_datetime(data3["TransactionDate"])
print(data3.dtypes)
# Out:
# CustomerID              object
# CustomerName            object
# Region                  object
# SignupDate      datetime64[ns]
# dtype: object
# TransactionID              object
# CustomerID                 object
# ProductID                  object
# TransactionDate    datetime64[ns]
# Quantity                    int64
# TotalValue                float64
# Price                     float64
# dtype: object

# %%
# Total Customer
Total_customer=data1["CustomerID"].nunique()
print("Total Customer:",Total_customer)
# Out:
# Total Customer: 200

# %%
# Total Products
Total_products=data2["ProductID"].nunique()
print("Total Products:",Total_products)
# Out:
# Total Products: 100

# %%
# Total Transection
Total_transactions=data3["TransactionID"].nunique()
print("Total Transection:",Total_transactions)
# Out:
# Total Transection: 1000

# %%
merge_data=data3.merge(data1,on="CustomerID",how="left") \
                .merge(data2,on="ProductID",how="left")
print(merge_data)
# Out:
#     TransactionID CustomerID ProductID     TransactionDate  Quantity  \
# 0          T00001      C0199      P067 2024-08-25 12:38:23         1
# 1          T00112      C0146      P067 2024-05-27 22:23:54         1
# 2          T00166      C0127      P067 2024-04-25 07:38:55         1
# 3          T00272      C0087      P067 2024-03-26 22:55:37         2
# 4          T00363      C0070      P067 2024-03-21 15:10:10         3
# ..            ...        ...       ...                 ...       ...
# 995        T00496      C0118      P037 2024-10-24 08:30:27         1
# 996        T00759      C0059      P037 2024-06-04 02:15:24         3
# 997        T00922      C0018      P037 2024-04-05 13:05:32         4
# 998        T00959      C0115      P037 2024-09-29 10:16:02         2
# 999        T00992      C0024      P037 2024-04-21 10:52:24         1
#
#      TotalValue  Price_x          CustomerName         Region SignupDate  \
# ...

# %%
# Total Revenue
Total_revenue=merge_data["TotalValue"].sum()
print("Total Revenue:",Total_revenue)
# Out:
# Total Revenue: 689995.56

# %%
# Avg Transaction Value
Avg_transaction_value=merge_data["TotalValue"].mean()
print("Avg Transaction Value:",Avg_transaction_value)
# Out:
# Avg Transaction Value: 689.9955600000001

# %%
# Top Regions by Transactions
Top_regions=merge_data["Region"].value_counts().head(5)
print("Top 5 Regions:",Top_regions)
# Out:
# Top 5 Regions: Region
# South America    304
# North America    244
# Europe           234
# Asia             218
# Name: count, dtype: int64

# %%
# Top Categories by Sales
top_categories=merge_data.groupby("Category")["TotalValue"].sum().sort_values(ascending=False).head(3)
print("Top Categories by Sales:",top_categories)
# Out:
# Top Categories by Sales: Category
# Books          192147.47
# Electronics    180783.50
# Clothing       166170.66
# Name: TotalValue, dtype: float64

# %%
Top_regions.plot(kind="bar",color="red",title="Top Regions by Transactions")
plt.xlabel("Region")
plt.ylabel("Total Transactions")
plt.show()

# %%
top_categories.plot(kind="pie",autopct='%1.1f%%',title="Top Categories by Sales")
plt.ylabel("")
plt.show()

# %%
merge_data["TransactionMonth"]=merge_data["TransactionDate"].dt.to_period("M")
revenue_trend=merge_data.groupby("TransactionMonth")["TotalValue"].sum()
print(revenue_trend)
# Out:
# TransactionMonth
# 2023-12     3769.52
# 2024-01    66376.39
# 2024-02    51459.27
# 2024-03    47828.73
# 2024-04    57519.06
# 2024-05    64527.74
# 2024-06    48771.18
# 2024-07    71366.39
# 2024-08    63436.74
# 2024-09    70603.75
# 2024-10    47063.22
# 2024-11    38224.37
# 2024-12    59049.20
# Freq: M, Name: TotalValue, dtype: float64

# %%
revenue_trend.plot(kind="line",marker="o",title="Revenue Trend Over Time")
plt.xlabel("Month")
plt.ylabel("Total Revenue")
plt.show()
